# %% [markdown]
# # Patient trajectory and condition analysis

# %% [markdown]
# ## Required libraries and packages

# %%
import pandas as pd
import numpy as np

import glob
import pprint 
import plotly
import plotly.express as px
import plotly.graph_objs as go


import folium
from folium.plugins import MarkerCluster
from itertools import chain
import math
from collections import Counter
from prettytable import PrettyTable
from ast import literal_eval
from IPython import display


import warnings
warnings.filterwarnings("ignore")

print("Pandas version:", pd.__version__)
print("Numpy version:", np.__version__)
print("plotly version:", plotly.__version__)
print("folium version:", folium.__version__)
# Out:
# Pandas version: 1.5.3
# Numpy version: 1.22.4
# plotly version: 5.13.1
# folium version: 0.14.0

# %% [markdown]
# # Utilities

# %%
def count_missing_values(data):
    """
    Counts the number of missing values in each column of a DataFrame and returns the results as a new DataFrame.
    """
    missing_values = data.isnull().sum()
    missing_df = pd.DataFrame({'column_name': missing_values.index, 'missing_count': missing_values.values})
    return missing_df

# %%
def is_float(string):
    """
    Check either is a string number or not
    """
    
    try:
        float(string)
        return True
    except ValueError:
        return False

def is_number(string):
    return string.isdigit() or is_float(string)


def count_values(value_list, topk=10, verbose=True, key_name="KEY", val_name="VALUE", ignore_number=False):
    # remove nan values
    values = [[v] if not isinstance(v, list) else v for v in value_list if v == v]
    # flatten the list of list into a list
    values = list(chain(*values))
    # ignore numbers
    if ignore_number:
        values = list(filter(lambda x: not is_float(x), values))
    
    counter = Counter()
    counter.update(values)
    most_common = counter.most_common(topk) if topk > 0 else counter.most_common()
    
    if verbose:
        tb = PrettyTable([key_name, val_name])
        for item in most_common:
            tb.add_row([item[0], item[1]])
        print(tb)

# %%
def contains_x(value, x):
    if value != value:
        return False
    
    if isinstance(value, str) and value == x:
        return False
    
    if isinstance(value, list) and x in value:
        return True
    
    return False

# %%
def fix_data_type(row):
    new_row = {}
    for key, value in row.to_dict().items():
        
        try:
            value = literal_eval(value)
        except (ValueError, SyntaxError):
            pass
        
        if "DATE" in key or "START" in key or "STOP" in key:
            if isinstance(value, list):
                value = [pd.to_datetime(v, errors='coerce') for v in value]
            else:
                value = pd.to_datetime(value, errors='coerce')
            
        new_row[key] = value
        
    return pd.Series(new_row)

# %% [markdown]
# # Load final dataset

# %%
data = pd.read_csv('final_data.csv', sep='\t') 
data = data.apply(fix_data_type, axis=1)
data.head(1)
# Out:
#                              PATIENT_Id PATIENT_BIRTHDATE PATIENT_DEATHDATE  \
# 0  034e9e3b-2def-4559-bb2a-7850888ae060        1983-11-14               NaT
#
#    PATIENT_SSN PATIENT_FIRST PATIENT_LAST PATIENT_MARITAL PATIENT_RACE  \
# 0  999-73-5361       Milo271      Feil794               M        white
#
#   PATIENT_ETHNICITY PATIENT_GENDER  ... ALLERGY_DESCRIPTION DEVICE_START  \
# 0       nonhispanic              M  ...                 NaN          NaT
#
#   DEVICE_STOP DEVICE_CODE DEVICE_DESCRIPTION  DEVICE_UDI  IMMUN_DATE  \
# 0         NaT         NaN                NaN         NaN         NaT
#
#    IMMUN_CODE  IMMUN_DESCRIPTION  IMMUN_BASE_COST
# 0         NaN                NaN              NaN
#
# [1 rows x 128 columns]

# %%
count_missing_values(data)
# Out:
#            column_name  missing_count
# 0           PATIENT_Id              0
# 1    PATIENT_BIRTHDATE              0
# 2    PATIENT_DEATHDATE          39059
# 3          PATIENT_SSN              0
# 4        PATIENT_FIRST              0
# ..                 ...            ...
# 123         DEVICE_UDI          53268
# 124         IMMUN_DATE          42978
# 125         IMMUN_CODE          42978
# 126  IMMUN_DESCRIPTION          42978
# 127    IMMUN_BASE_COST          42978
#
# [128 rows x 2 columns]

# %%
print(data.dtypes.value_counts())
# Out:
# object                 91
# float64                18
# int64                  14
# datetime64[ns]          3
# datetime64[ns, UTC]     2
# dtype: int64

# %% [markdown]
# # Patient trjectory
#
# Patient trajectory refers to the path that a patient takes through the healthcare system over time, including their interactions with different healthcare providers and the healthcare services they receive. The patient trajectory can be complex and may involve multiple transitions between different levels of care, such as hospitalization, outpatient care, rehabilitation, and long-term care.

# %%
data.groupby("PATIENT_Id").size().reset_index(name='count').sort_values('count', ascending=False).head(20)
# Out:
#                                 PATIENT_Id  count
# 924   cae10920-f977-48b4-a0d3-4d70ad561fd1   2006
# 120   19d2cfb8-439b-454a-b47e-5274c219005b   1606
# 268   3f336702-bf73-4fc8-bd59-3ba77fd65d0d   1538
# 253   3acf9313-1874-4dff-ab2a-3187516d92d6    826
# 942   cecb7ece-fb70-4a7f-b51d-6e8dd1506ad9    452
# 261   3dd2dd29-7cd0-48f7-b859-136c6e9d36e0    385
# 470   714b9c18-783d-4f52-aa64-cc3a05a286d9    375
# 199   2c71dd97-7085-416a-aa07-d675bbe3adf2    367
# 461   6ec18ddf-e9ee-421a-9033-456f558c7b4b    367
# 89    137acc1b-dbca-473e-84bb-fe1baaf98819    346
# 90    13a3a783-ecc5-4ec5-b3dc-168b15cebb88    303
# 376   59cf17d9-6c13-4333-a1cb-cc5fdf63366d    299
# 745   a708bca4-8fc9-4567-8c22-8b13d44f4f45    285
# 550   80427c8e-15ba-482f-b168-fc4f1d375179    206
# 1163  fd3acd35-add1-4634-8c90-68ed0f638fde    182
# 822   b656a85d-637d-458a-abd8-17219816280f    171
# 860   be3eaf02-0c8a-4729-8b6e-7b40ab016e29    169
# 919   ca24f616-30cc-4351-aca9-1b49297de076    169
# 748   a7f102bb-e1ba-4417-a0c5-75dec6473034    169
# 710   9fda53d4-6fcc-4ef5-a1fe-16e007182ec2    166

# %%
patient_id = '034e9e3b-2def-4559-bb2a-7850888ae060'
patient = data[data['PATIENT_Id'] == patient_id]
enconter_columns = list(filter(lambda x: "ENCOUNTER" in x, patient.columns.tolist()))
display.display(patient[enconter_columns].head())
if not patient.empty:
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_START'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Start'))
    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_STOP'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Stop'))

    for _, row in patient.iterrows():
        fig.add_shape(
            type='line',
            x0=row['ENCOUNTER_START'], x1=row['ENCOUNTER_STOP'],
            y0=row['ENCOUNTER_Id'], y1=row['ENCOUNTER_Id'],
            yref='y', xref='x',
            line=dict(color='black', width=1)
        )

    fig.update_layout(
        title=f'Trajectory for patient {patient_id}',
        xaxis_title='Timeline',
        yaxis_title='',
        yaxis=dict(tickmode='linear')
    )

    # set the x-axis range
    min_date = patient['ENCOUNTER_START'].min() - pd.Timedelta(days=30)
    max_date = patient['ENCOUNTER_STOP'].max() + pd.Timedelta(days=30)

    fig.update_xaxes(range=[min_date, max_date])
    fig.update_yaxes(title_text='', showticklabels=False)
    
    fig.show()
else:
    print("No encounters found")
# Out:
#                             ENCOUNTER_Id           ENCOUNTER_START  \
# 0   d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28+00:00
# 1   e88bc3a9-007c-405e-aabc-792a38f4aa2b 2012-01-23 17:45:28+00:00
# 14  e3639187-450a-4aa9-9fc9-3ea3cafa672b 2015-01-26 17:45:28+00:00
# 26  3b639086-5fbc-4720-8c31-e8c8c0f1d660 2016-12-29 17:45:28+00:00
# 35  4607e1a1-f2bb-42c8-a2fd-8709331a935d 2017-01-09 17:45:28+00:00
#
#               ENCOUNTER_STOP ENCOUNTER_ENCOUNTERCLASS  ENCOUNTER_CODE  \
# 0  2010-01-23 18:10:28+00:00               ambulatory       185345009
# 1  2012-01-23 18:00:28+00:00                 wellness       162673000
# 14 2015-01-26 18:15:28+00:00                 wellness       162673000
# 26 2016-12-29 18:00:28+00:00               ambulatory       185345009
# 35 2017-01-09 18:00:28+00:00               outpatient       185349003
#
#                          ENCOUNTER_DESCRIPTION  ENCOUNTER_BASE_ENCOUNTER_COST  \
# 0                        Encounter for symptom                         129.16
# 1   General examination of patient (procedure)                         129.16
# 14  General examination of patient (procedure)                         129.16
# 26                       Encounter for symptom                         129.16
# 35          Encounter for check up (procedure)                         129.16
#
#     ENCOUNTER_TOTAL_CLAIM_COST  ENCOUNTER_PAYER_COVERAGE  \
# 0                       129.16                     54.16
# 1                       129.16                    129.16
# 14                      129.16                    129.16
# 26                      129.16                     54.16
# 35                      129.16                     54.16
#
#     ENCOUNTER_REASONCODE  ENCOUNTER_REASONDESCRIPTION  \
# 0             10509002.0  Acute bronchitis (disorder)
# 1                    NaN                          NaN
# 14                   NaN                          NaN
# 26            10509002.0  Acute bronchitis (disorder)
# 35                   NaN                          NaN
#
#     PAYER_COVERED_ENCOUNTERS  PAYER_UNCOVERED_ENCOUNTERS
# 0                      16168                           0
# 1                      16168                           0
# 14                     16168                           0
# 26                     16168                           0
# 35                     16168                           0
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9e7b5e88-9475-4ba1-8bce-f2244e0aff0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e7b5e88-9475-4ba1-8bce-f2244e0aff0e")) {                    Plotly.newPlot(                        "9e7b5e88-9475-4ba1-8bce-f2244e0aff0e",                        [{"mode":"markers","name":"Start","text":["ambulatory","wellness","wellness","ambulatory","outpatient","wellness"],"x":["2010-01-23T17:45:28+00:00","2012-01-23T17:45:28+00:00","2015-01-26T17:45:28+00:00","2016-12-29T17:45:28+00:00","2017-01-09T17:45:28+00:00","2018-01-29T17:45:28+00:00"],"y":["d0c40d10-8d87-447e-836e-99d26ad52ea5","e88bc3a9-007c-405e-aabc-792a38f4aa2b","e3639187-450a-4aa9-9fc9-3ea3cafa672b","3b639086-5fbc-4720-8c31-e8c8c0f1d660","4607e1a1-f2bb-42c8-a2fd-8709331a935d","1b3d7c95-f4d3-4dfb-83de-8773f5ce01f7"],"type":"scatter"},{"mode":"markers","name":"Stop","text":["ambulatory","wellness","wellness","ambulatory","outpatient","wellness"],"x":["2010-01-23T18:10:28+00:00","2012-01-23T18:00:28+00:00","2015-01-26T18:15:28+00:00","2016-12-29T18:00:28+00:00","2017-01-09T18:00:28+00:00","2018-01-29T18:00:28+00:00"],"y":["d0c40d10-8d87-447e-836e-99d26ad52ea5","e88bc3a9-007c-405e-aabc-792a38f4aa2b","e3639187-450a-4aa9-9fc9-3ea3cafa672b","3b639086-5fbc-4720-8c31-e8c8c0f1d660","4607e1a1-f2bb-42c8-a2fd-8709331a935d","1b3d7c95-f4d3-4dfb-83de-8773f5ce01f7"],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953" ...

# %%
patient_id = "9fda53d4-6fcc-4ef5-a1fe-16e007182ec2"
patient = data[data["PATIENT_Id"] == patient_id]
enconter_columns = list(filter(lambda x: "ENCOUNTER" in x, patient.columns.tolist()))
display.display(patient[enconter_columns].head())
if not patient.empty:
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_START'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Start'))
    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_STOP'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Stop'))

    for _, row in patient.iterrows():
        fig.add_shape(
            type='line',
            x0=row['ENCOUNTER_START'], x1=row['ENCOUNTER_STOP'],
            y0=row['ENCOUNTER_Id'], y1=row['ENCOUNTER_Id'],
            yref='y', xref='x',
            line=dict(color='black', width=1)
        )

    fig.update_layout(
        title=f'Trajectory for patient {patient_id}',
        xaxis_title='Timeline',
        yaxis_title='',
        yaxis=dict(tickmode='linear')
    )

    # set the x-axis range
    min_date = patient['ENCOUNTER_START'].min() - pd.Timedelta(days=30)
    max_date = patient['ENCOUNTER_STOP'].max() + pd.Timedelta(days=30)

    fig.update_xaxes(range=[min_date, max_date])
    fig.update_yaxes(title_text='', showticklabels=False)
    
    fig.show()
else:
    print("No encounters found")
# Out:
#                                ENCOUNTER_Id           ENCOUNTER_START  \
# 12191  6bf0fde0-52f9-463c-8aa8-64fe948d5171 2000-02-25 11:19:49+00:00
# 12192  da2fa819-307a-410d-9b95-6ea21a2f19ae 2000-03-10 11:19:49+00:00
# 12193  c5523cfc-caba-4404-a7d2-1265b5ebe274 2001-05-30 11:19:49+00:00
# 12194  06c240ca-8175-4e6e-83de-8f1ceb2677fd 2003-05-30 11:19:49+00:00
# 12195  9946bd5c-fd8d-41d8-9222-400c9b064fb2 2004-05-03 11:19:49+00:00
#
#                  ENCOUNTER_STOP ENCOUNTER_ENCOUNTERCLASS  ENCOUNTER_CODE  \
# 12191 2000-02-25 11:34:49+00:00               ambulatory       185347001
# 12192 2000-03-10 12:06:49+00:00               ambulatory       185347001
# 12193 2001-06-13 11:19:49+00:00               ambulatory       185345009
# 12194 2003-05-30 11:49:49+00:00               ambulatory       185345009
# 12195 2004-05-03 11:34:49+00:00                 wellness       410620009
#
#               ENCOUNTER_DESCRIPTION  ENCOUNTER_BASE_ENCOUNTER_COST  \
# 12191         Encounter for problem                         129.16
# 12192         Encounter for problem                         129.16
# 12193         Encounter for symptom                         129.16
# 12194         Encounter for symptom                         129.16
# 12195  Well child visit (procedure)                         129.16
#
#        ENCOUNTER_TOTAL_CLAIM_COST  ENCOUNTER_PAYER_COVERAGE  \
# 12191                      129.16                      0.00
# 12192                      129.16                      0.00
# 12193                      129.16                      0.00
# 12194                      129.16                      0.00
# 12195                      129.16                     74.16
#
#        ENCOUNTER_REASONCODE  \
# 12191            24079001.0
# 12192                   NaN
# 12193           232353008.0
# 12194           233678006.0
# 12195                   NaN
#
#                              ENCOUNTER_REASONDESCRIPTION  \
# 12191                                  Atopic dermatitis
# 12192                                                NaN
# 12193  Perennial allergic rhinitis with seasonal vari...
# 12194                                   Childhood asthma
# 12195                                                NaN
#
#        PAYER_COVERED_ENCOUNTERS  PAYER_UNCOVERED_ENCOUNTERS
# 12191                         0                       10116
# 12192                         0                       10116
# 12193                         0                       10116
# 12194                         0                       10116
# 12195                      6085                        7422
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="46d57f1f-a8f9-41df-8c32-4c7010b54186" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46d57f1f-a8f9-41df-8c32-4c7010b54186")) {                    Plotly.newPlot(                        "46d57f1f-a8f9-41df-8c32-4c7010b54186",                        [{"mode":"markers","name":"Start","text":["ambulatory","ambulatory","ambulatory","ambulatory","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","urgentcare","ambulatory","outpatient","ambulatory","ambulatory","ambulatory","wellness","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","outpatient","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","wellness","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","wellness","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","emergency","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","wellness","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","outpatient","ambulatory","ambulatory","wellness","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","ambulatory","urgentcare","ambulatory","outpatient","outpatient","ambulatory","ambulatory","wellness","ambulatory","ambulatory","emergency","wellness","ambulatory","urgentcare","outpatient","wellness","ambulatory"],"x":["2000-02-25T11:19:49+00:00","2000-03-10T11:19:49+00:00","2001-05-30T11:19:49+00:00","2003-05-30T11:19:49+00:00","2004-05-03T11:19:49+00:00","2005-05-09T11:19:49+00:00","2006-05-15T11:19:49+00:00","2007-05-21T11:19:49+00:00","2008-05-26T11:19:49+00:00","2009-06-01T11:19:49+00:00","2010-06-07T11:19:49+00:00","2011-06-13T11:19:49+00:00","2011-08-29T11:19:49+00:00","2011-08-25T11:19:49+00:00","2011-09-05T11:19:49+00:00","2012-04-13T11:19:49+00:00","2012-05-20T11:19:49+00:00","2012-05-28T11:19:49+00:00","2012-06-18T11:19:49+00:00","2012-06-18T11:19:49+00:00","2012-06-17T11:19:49+00:00","2012-07-09T11:19:49+00:00","2012-07-15T11:19:49+00:00","2012-07-30T11:19:49+00:00","2012-08-20T11:19:49+00:00","2012-08-19T11:19:49+00:00","2012-09-10T11:19:49+00:00","2012-09-16T11:19:49+00:00","2012-10-01T11:19:49+00:00","2012-10-22T11:19:49+00:00","2012-10-21T11:19:49+00:00","2012-11-12T11:19:49+00:00","2012-11-25T11:19:49+00:00","2012-12-03T11:19:49+00:00","2012-12-24T11:19:49+00:00","2012-12-23T11:19:49+00:00","2013-01-07T11:19:49+00:00","2013-01-14T11:19:49+00:00","2013-01-14T11:19:49+00:00","2013-01-27T11:19:49+00:00","2013-02-04T11:19:49+00:00","2013-02-25T11:19:49+00:00","2013-02-24T11:19:49+00:00","2013-03-18T11:19:49+00:00","2013-03-24T11:19:49+00:00","2013-04-08T11:19:49+ ...

# %%
patient_id = "3acf9313-1874-4dff-ab2a-3187516d92d6"
patient = data[data["PATIENT_Id"] == patient_id]
enconter_columns = list(filter(lambda x: "ENCOUNTER" in x, patient.columns.tolist()))
display.display(patient[enconter_columns].head())
if not patient.empty:
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_START'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Start'))
    fig.add_trace(go.Scatter(x=patient['ENCOUNTER_STOP'], y=patient['ENCOUNTER_Id'], text=patient['ENCOUNTER_ENCOUNTERCLASS'], mode='markers', name='Stop'))

    for _, row in patient.iterrows():
        fig.add_shape(
            type='line',
            x0=row['ENCOUNTER_START'], x1=row['ENCOUNTER_STOP'],
            y0=row['ENCOUNTER_Id'], y1=row['ENCOUNTER_Id'],
            yref='y', xref='x',
            line=dict(color='black', width=1)
        )

    fig.update_layout(
        title=f'Trajectory for patient {patient_id}',
        xaxis_title='Timeline',
        yaxis_title='',
        yaxis=dict(tickmode='linear')
    )

    # set the x-axis range
    min_date = patient['ENCOUNTER_START'].min() - pd.Timedelta(days=30)
    max_date = patient['ENCOUNTER_STOP'].max() + pd.Timedelta(days=30)

    fig.update_xaxes(range=[min_date, max_date])
    fig.update_yaxes(title_text='', showticklabels=False)
    
    fig.show()
else:
    print("No encounters found")
# Out:
#                                ENCOUNTER_Id           ENCOUNTER_START  \
# 41442  9911370d-0d61-475f-8982-50d8d9ec0f51 1934-06-25 13:57:11+00:00
# 41443  d7fe5ec7-27b4-4ab2-b9cc-3d6fea8a2e05 1935-07-01 13:57:11+00:00
# 41444  30d7c24e-64a8-42d0-a282-10f2a453129a 1936-07-06 13:57:11+00:00
# 41445  95913884-94cd-45b7-bafe-1faa88413e05 1937-07-12 13:57:11+00:00
# 41446  bf3eb140-5545-4964-888f-f2e28b1b24b0 1938-07-18 13:57:11+00:00
#
#                  ENCOUNTER_STOP ENCOUNTER_ENCOUNTERCLASS  ENCOUNTER_CODE  \
# 41442 1934-06-25 14:27:11+00:00                 wellness       410620009
# 41443 1935-07-01 14:12:11+00:00                 wellness       162673000
# 41444 1936-07-06 14:27:11+00:00                 wellness       162673000
# 41445 1937-07-12 14:27:11+00:00                 wellness       162673000
# 41446 1938-07-18 14:12:11+00:00                 wellness       162673000
#
#                             ENCOUNTER_DESCRIPTION  \
# 41442                Well child visit (procedure)
# 41443  General examination of patient (procedure)
# 41444  General examination of patient (procedure)
# 41445  General examination of patient (procedure)
# 41446  General examination of patient (procedure)
#
#        ENCOUNTER_BASE_ENCOUNTER_COST  ENCOUNTER_TOTAL_CLAIM_COST  \
# 41442                         129.16                      129.16
# 41443                         129.16                      129.16
# 41444                         129.16                      129.16
# 41445                         129.16                      129.16
# 41446                         129.16                      129.16
#
#        ENCOUNTER_PAYER_COVERAGE  ENCOUNTER_REASONCODE  \
# 41442                     69.16                   NaN
# 41443                     69.16                   NaN
# 41444                     69.16                   NaN
# 41445                     69.16                   NaN
# 41446                     69.16                   NaN
#
#       ENCOUNTER_REASONDESCRIPTION  PAYER_COVERED_ENCOUNTERS  \
# 41442                         NaN                     11971
# 41443                         NaN                     11971
# 41444                         NaN                     11971
# 41445                         NaN                     11971
# 41446                         NaN                     11971
#
#        PAYER_UNCOVERED_ENCOUNTERS
# 41442                        1745
# 41443                        1745
# 41444                        1745
# 41445                        1745
# 41446                        1745
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="96345165-4d69-4839-8ba2-823919ca65ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96345165-4d69-4839-8ba2-823919ca65ee")) {                    Plotly.newPlot(                        "96345165-4d69-4839-8ba2-823919ca65ee",                        [{"mode":"markers","name":"Start","text":["wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","outpatient","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","wellness","ambulatory","wellness","wellness","ambulatory","outpatient","wellness","wellness","outpatient","ambulatory","wellness","wellness","wellness","wellness","wellness","wellness","outpatient","outpatient","ambulatory","wellness","wellness","wellness","wellness","wellness","outpatient","outpatient","wellness","wellness","wellness","wellness","wellness","outpatient","outpatient","wellness","outpatient","wellness","wellness","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","ambulatory","outpatient","outpatient","wellness","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","wellness","ambulatory","ambulatory","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","urgentcare","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","ambulatory","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","outpatient","outpatient","outpatient","wellness","outpatient","outpatient","outpatient","urgentcare","outpatient","emergency","urgentcare","outpatient","emergency","urgentcare","urgentcare","urgentcare","emergency","emergency","urgentcare","urgentcare","emergency","emergency","urgentcare","urgentcare","emergency","emergency","urgentcare","outpatient","emergency","urgentcare","urgentcare","outpatient","wellness","emergency","urgentcare","urgentcare","emergency","urgentcare","urgentcare","urgentcare","emergency","urgentcare","urgentca ...

# %% [markdown]
# # Top conditions analysis
#
# **Analysis**
#
# - **Symptoms:** there is some similarity between these three disorders as all of them are caused by viruses and affect the respiratory system. Acute bronchitis is an inflammation of the bronchial tubes, Acute viral pharyngitis is an inflammation of the pharynx (back of the throat), and Viral sinusitis is an inflammation of the sinuses. They may share similar symptoms like cough, sore throat, congestion, and fatigue.
# - **Location:** Most of patients in three top conditions are located in Massachusetts. In Massachusetts, the climate is generally humid, with warm summers and cold winters. The humidity levels can vary throughout the year, with higher levels in the summer months. The climate is influenced by the state's location on the East Coast of the United States, with the Atlantic Ocean to the east and the Appalachian Mountains to the west.This can lead to increased moisture in the sinuses, which can exacerbate sinusitis symptoms. Additionally, temperature changes and barometric pressure changes, which can occur frequently in Massachusetts, can also trigger infections symptoms in some individuals.
# - **Severity:** In all three conditions most of patients are able to walk and move around without assistance or support.
# - **Weather:** They are more likely to occur during the colder months of the year when people spend more time indoors in close proximity to one another, which increases the risk of transmission of the viruses that cause these infections. Beased on the information condition one is mostly happened in spring and winter,, condition two happend in winter mostly and condition three happend in spring and summer.
# - **Immune system:** Unfortunetly, there are not enough information for conclusion.
# - **Life-style:** Other factors that can increase the risk of these infections are exposuring to irritants such as cigarette smoke or pollution.
# Most of the patients are not smoker. But based on the infromation we could not make the conclusion that the life style is not matter in these conditions.
# - **Allergy:** Unfortunetly, there are not enough information for conclusion.

# %% [markdown]
# # Preprocessing stage
#
# The information for patient contains:
# - Admission / discharge time
# - Dermographic infomration
# - Hospital / insurance information
# - Vital sign observation
# - Medication duration and type of medication
# - Careplan timeline (in or outside of hospital)
# - Device and immunization related to surgery / tracking or patient

# %%
data.iloc[0].to_dict()
# Out:
# {'PATIENT_Id': '034e9e3b-2def-4559-bb2a-7850888ae060',
#  'PATIENT_BIRTHDATE': Timestamp('1983-11-14 00:00:00'),
#  'PATIENT_DEATHDATE': NaT,
#  'PATIENT_SSN': '999-73-5361',
#  'PATIENT_FIRST': 'Milo271',
#  'PATIENT_LAST': 'Feil794',
#  'PATIENT_MARITAL': 'M',
#  'PATIENT_RACE': 'white',
#  'PATIENT_ETHNICITY': 'nonhispanic',
#  'PATIENT_GENDER': 'M',
#  'PATIENT_BIRTHPLACE': 'Danvers  Massachusetts  US',
#  'PATIENT_ADDRESS': '422 Farrell Path Unit 69',
#  'PATIENT_CITY': 'Somerville',
#  'PATIENT_STATE': 'Massachusetts',
#  'PATIENT_COUNTY': 'Middlesex County',
#  'PATIENT_LAT': 42.36069732777065,
#  'PATIENT_LON': -71.12653095133149,
#  'PATIENT_HEALTHCARE_EXPENSES': 793946.01,
#  'PATIENT_HEALTHCARE_COVERAGE': 3204.49,
#  'PATIENT_AGE': 39,
#  'ENCOUNTER_Id': 'd0c40d10-8d87-447e-836e-99d26ad52ea5',
#  'ENCOUNTER_START': Timestamp('2010-01-23 17:45:28+0000', tz='UTC'),
#  'ENCOUNTER_STOP': Timestamp('2010-01-23 18:10:28+0000', tz='UTC'),
#  'ENCOUNTER_ENCOUNTERCLASS': 'ambulatory',
#  'ENCOUNTER_CODE': 185345009,
#  'ENCOUNTER_DESCRIPTION': 'Encounter for symptom',
#  'ENCOUNTER_BASE_ENCOUNTER_COST': 129.16,
#  'ENCOUNTER_TOTAL_CLAIM_COST': 129.16,
#  'ENCOUNTER_PAYER_COVERAGE': 54.16,
#  'ENCOUNTER_REASONCODE': 10509002.0,
#  'ENCOUNTER_REASONDESCRIPTION': 'Acute bronchitis (disorder)',
#  'ORGANIZATION_Id': 'e002090d-4e92-300e-b41e-7d1f21dee4c6',
#  'ORGANIZATION_NAME': 'CAMBRIDGE HEALTH ALLIANCE',
#  'ORGANIZATION_ADDRESS': '1493 CAMBRIDGE STREET',
#  'ORGANIZATION_CITY': 'CAMBRIDGE',
#  'ORGANIZATION_STATE': 'MA',
#  'ORGANIZATION_ZIP': '02138',
#  'ORGANIZATION_LAT': 42.375967,
#  'ORGANIZATION_LON': -71.118275,
#  'ORGANIZATION_PHONE': 6176652300,
#  'ORGANIZATION_REVENUE': 406053.1899999777,
#  'ORGANIZATION_UTILIZATION': 3199,
#  'PROVIDER_Id': 'e6283e46-fd81-3611-9459-0edb1c3da357',
#  'PROVIDER_NAME': 'Jeanmarie510 Beatty507',
#  'PROVIDER_GENDER': 'F',
#  'PROVIDER_SPECIALITY': 'GENERAL PRACTICE',
#  'PROVIDER_ADDRESS': '1493 CAMBRIDGE STREET',
#  'PROVIDER_CITY': 'CAMBRIDGE',
#  'PROVIDER_STATE': 'MA',
#  'PROVIDER_ZIP': '02138',
#  'PROVIDER_LAT': 42.375967,
#  'PROVIDER_LON': -71.118275,
#  'PROVIDER_UTILIZATION': 3199,
#  'PAYER_Id': '6e2f1a2d-27bd-3701-8d08-dae202c58632',
#  'PAYER_NAME': 'Blue Cross Blue Shield',
#  'PAYER_ADDRESS': 'Michigan Plaza',
#  'PAYER_CITY': 'Chicago',
#  'PAYER_STATE_HEADQUARTERED': 'IL',
#  'PAYER_ZIP': 60007.0,
#  'PAYER_PHONE': '1-800-262-2583',
#  'PAYER_AMOUNT_COVERED': 2741717.82,
#  'PAYER_AMOUNT_UNCOVERED': 1431463.91,
#  'PAYER_REVENUE': 140652000.0,
#  'PAYER_COVERED_ENCOUNTERS': 16168,
#  'PAYER_UNCOVERED_ENCOUNTERS': 0,
#  'PAYER_COVERED_MEDICATIONS': 6159,
#  'PAYER_UNCOVERED_MEDICATIONS': 0,
#  'PAYER_COVERED_PROCEDURES': 15312,
#  'PAYER_UNCOVERED_PROCEDURES': 0,
#  'PAYER_COVERED_IMMUNIZATIONS': 7520,
#  'PAYER_UNCOVERED_IMMUNIZATIONS': 0,
#  'PAYER_UNIQUE_CUSTOMERS': 307,
#  'PAYER_QOLS_AVG': 0.9072563661939262,
#  'PAYER_MEMBER_MONTHS': 78768,
#  'OBS_DATE': NaT,
#  'OBS_CODE': nan,
#  'OBS_DESCRIPTION': nan,
#  'OBS_VALUE': nan,
#  'OBS_UNITS': nan,
#  'OBS_TYPE': nan,
#  'COND_START': NaT,
#  'COND_STOP': NaT,
#  'COND_CODE': nan,
#  'COND_DESCRIPTION': nan,
#  'MEDICATION_START': NaT,
#  'MEDICATION_STOP': NaT,
#  'MEDICATION_CODE': nan,
#  'MEDICATION_DESCRIPTION': nan,
#  'MEDICATION_BASE_COST': nan,
#  'MEDICATION_PAYER_COVERAGE': nan,
#  'MEDICATION_DISPENSES': nan,
#  'MEDICATION_TOTALCOST': nan,
#  'MEDICATION_REASONCODE': nan,
#  'MEDICATION_REASONDESCRIPTION': nan,
#  'IMG_Id': nan,
#  'IMG_DATE': NaT,
#  'IMG_BODYSITE_CODE': nan,
#  'IMG_BODYSITE_DESCRIPTION': nan,
#  'IMG_MODALITY_CODE': nan,
#  'IMG_MODALITY_DESCRIPTION': nan,
#  'IMG_SOP_CODE': nan,
#  'IMG_SOP_DESCRIPTION': nan,
#  'PROC_DATE': NaT,
#  'PROC_CODE': nan,
#  'PROC_DESCRIPTION': nan,
#  'PROC_BASE_COST': nan,
#  'PROC_REASONCODE': nan,
#  'PROC_REASONDESCRIPTION': nan,
#  'CAREPLAN_Id': ['d2500b8c-e830-433a-8b9d-368d30741520'],
#  'CAREPLAN_START': [Timestamp('2010-01-23 00:00:00')],
#  'CAREPLAN_STOP': [Timestamp('2012-01-23 00:00:00')],
#  'CAREPLAN_CODE': [53950000],
#  'CAREPLAN_DESCRIPTION': ['Respiratory therapy'],
#  'CAREPLAN_REASONCODE': [10509002.0],
#  'CAREPLAN_REASONDESCRIPTION': ['Acute bronchitis (disorder)'],
#  'ALLERGY_START': NaT,
#  'ALLERGY_STOP': NaT,
#  'ALLERGY_CODE': nan,
#  'ALLERGY_DESCRIPTION': nan,
#  'DEVICE_START': NaT,
#  'DEVICE_STOP': NaT,
#  'DEVICE_CODE': nan,
#  'DEVICE_DESCRIPTION': nan,
#  'DEVICE_UDI': nan,
#  'IMMUN_DATE': NaT,
#  'IMMUN_CODE': nan,
#  'IMMUN_DESCRIPTION': nan,
#  'IMMUN_BASE_COST': nan}

# %% [markdown]
# # Summary of patient condition
#
# According to result top three conditions are:
#
# - **Viral sinusitis (disorder)**
# - **Acute viral pharyngitis (disorder)**
# - **Acute bronchitis (disorder)**

# %%
print('Encounter description: ')
_ = count_values(data['ENCOUNTER_DESCRIPTION'], topk=10)
print()
print('Careplan description: ')
_ = count_values(data['CAREPLAN_DESCRIPTION'], topk=10)
print()
print('Condition description: ')
_ = count_values(data['COND_DESCRIPTION'], topk=10)
print()
# Out:
# Encounter description:
# +--------------------------------------------+-------+
# |                    KEY                     | VALUE |
# +--------------------------------------------+-------+
# | General examination of patient (procedure) | 14946 |
# |     Encounter for problem (procedure)      |  5196 |
# |     Encounter for check up (procedure)     |  4515 |
# |        Well child visit (procedure)        |  4144 |
# |           Encounter for symptom            |  3929 |
# |               Prenatal visit               |  2676 |
# |       Urgent care clinic (procedure)       |  2373 |
# |           Encounter for problem            |  2291 |
# |            Follow-up encounter             |  2282 |
# |        Patient encounter procedure         |  1624 |
# +--------------------------------------------+-------+
#
# Careplan description:
# +--------------------------------------------+-------+
# |                    KEY                     | VALUE |
# +--------------------------------------------+-------+
# |            Respiratory therapy             |  633  |
# |           Routine antenatal care           |  397  |
# |       Diabetes self management plan        |  339  |
# | Lifestyle education regarding hypertension |  302  |
# |         Physical therapy procedure         |  230  |
# |    Self-care interventions (procedure)     |  189  |
# |            Musculoskeletal care            |  187  |
# |                 Wound care                 |  185  |
# |               Fracture care                |  169  |
# |  Hyperlipidemia clinical management plan   |  136  |
# +--------------------------------------------+-------+
#
# Condition description:
# +-----------------------------------------+-------+
# |                   KEY                   | VALUE |
# +-----------------------------------------+-------+
# |        Viral sinusitis (disorder)       |  1248 |
# |    Acute viral pharyngitis (disorder)   |  653  |
# |       Acute bronchitis (disorder)       |  563  |
# |             Normal pregnancy            |  516  |
# | Body mass index 30+ - obesity (finding) |  449  |
# |               Prediabetes               |  317  |
# |               Hypertension              |  302  |
# |            Anemia (disorder)            |  300  |
# |       Chronic sinusitis (disorder)      |  236  |
# |      Miscarriage in first trimester     |  221  |
# +-----------------------------------------+-------+

# %% [markdown]
# # Invistigate first condition: Viral sinusitis (disorder)
#
# Sinusitis is an inflammation of the sinuses, which can be caused by several factors, including infections, allergies, and environmental irritants. Weather conditions, such as humidity, temperature changes, and barometric pressure changes, can also affect sinusitis symptoms.
#
#
# **Analysis**
#
# ```bash
# Medication:
# +----------------------------------------------------------------------------------------+-------+
# |                                          KEY                                           | VALUE |
# +----------------------------------------------------------------------------------------+-------+
# |                                          None                                          |  946  |
# |                  Amoxicillin 250 MG / Clavulanate 125 MG Oral Tablet                   |  247  |
# |         120 ACTUAT Fluticasone propionate 0.044 MG/ACTUAT Metered Dose Inhaler         |   20  |
# |           NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler           |   20  |
# |                   Atenolol 50 MG / Chlorthalidone 25 MG Oral Tablet                    |   16  |
# +----------------------------------------------------------------------------------------+-------+
#
# Median age:
# AGE (median): 50
#
# Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  1248 |
# +---------------+-------+
#
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   4   |  126  |
# |   7   |  114  |
# |   11  |  110  |
# |   5   |  105  |
# +-------+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  1248 |
# +------------+-------+
#
# Life-style patients:
# +--------------------------+-------+
# |           KEY            | VALUE |
# +--------------------------+-------+
# |       Never smoker       |  108  |
# |      Former smoker       |   34  |
# | Current every day smoker |   1   |
# +--------------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
#
# ```

# %%
condition_one = data[data["COND_DESCRIPTION"].apply(lambda x: contains_x(x, "Viral sinusitis (disorder)"))]
condition_one.head(1)
# Out:
#                              PATIENT_Id PATIENT_BIRTHDATE PATIENT_DEATHDATE  \
# 7  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        1978-05-27               NaT
#
#    PATIENT_SSN PATIENT_FIRST   PATIENT_LAST PATIENT_MARITAL PATIENT_RACE  \
# 7  999-85-4926    Mariana775  Rutherford999               M        white
#
#   PATIENT_ETHNICITY PATIENT_GENDER  ... ALLERGY_DESCRIPTION DEVICE_START  \
# 7       nonhispanic              F  ...                 NaN          NaN
#
#   DEVICE_STOP DEVICE_CODE DEVICE_DESCRIPTION  DEVICE_UDI  IMMUN_DATE  \
# 7         NaT         NaN                NaN         NaN         NaN
#
#    IMMUN_CODE  IMMUN_DESCRIPTION  IMMUN_BASE_COST
# 7         NaN                NaN              NaN
#
# [1 rows x 128 columns]

# %%
print("Medication: ")
_ = count_values(condition_one['MEDICATION_DESCRIPTION'], topk=10)

print()
print(" Median age: ")
print(f"AGE (median): {int(condition_one['PATIENT_AGE'].median())}")

print()
print(" Patient state: ")
_ = count_values(condition_one['PATIENT_STATE'], topk=1)
# Out:
# Medication:
# +----------------------------------------------------------------------------------------+-------+
# |                                          KEY                                           | VALUE |
# +----------------------------------------------------------------------------------------+-------+
# |                  Amoxicillin 250 MG / Clavulanate 125 MG Oral Tablet                   |  247  |
# |         120 ACTUAT Fluticasone propionate 0.044 MG/ACTUAT Metered Dose Inhaler         |   20  |
# |           NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler           |   20  |
# |                   Atenolol 50 MG / Chlorthalidone 25 MG Oral Tablet                    |   16  |
# |                       Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray                        |   12  |
# |                         Hydrochlorothiazide 25 MG Oral Tablet                          |   11  |
# | amLODIPine 5 MG / Hydrochlorothiazide 12.5 MG / Olmesartan medoxomil 20 MG Oral Tablet |   11  |
# |                             Clopidogrel 75 MG Oral Tablet                              |   9   |
# |                             Simvastatin 20 MG Oral Tablet                              |   9   |
# |                              Amlodipine 5 MG Oral Tablet                               |   9   |
# +----------------------------------------------------------------------------------------+-------+
#
#  Median age:
# AGE (median): 50
#
#  Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  1248 |
# +---------------+-------+

# %%
fig = px.histogram(condition_one, x="PATIENT_AGE", nbins=200, marginal="box", color_discrete_sequence=["#FF1493"])

fig.update_layout(
    title="Age Distribution",
    xaxis_title="Age",
    yaxis_title="Count",
    font=dict(
        family="Arial",
        size=14,
        color="#6495ED"
    ),
    bargap=0.1
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e5b3730a-43eb-4204-9ab4-691b2f47df7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5b3730a-43eb-4204-9ab4-691b2f47df7e")) {                    Plotly.newPlot(                        "e5b3730a-43eb-4204-9ab4-691b2f47df7e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"PATIENT_AGE=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#FF1493","pattern":{"shape":""}},"name":"","nbinsx":200,"offsetgroup":"","orientation":"v","showlegend":false,"x":[44,26,33,30,33,18,31,40,40,40,64,64,64,63,63,69,69,22,24,24,22,24,24,52,52,37,39,39,39,22,56,56,56,49,49,57,30,55,35,35,17,17,9,54,54,43,43,50,36,36,36,40,11,11,11,41,44,44,47,47,47,47,47,47,71,71,27,27,27,13,14,14,55,55,55,64,64,25,25,16,32,32,32,32,32,32,46,68,68,82,65,55,48,39,39,39,54,80,82,82,66,66,76,18,26,38,5,25,19,19,19,67,29,38,13,50,50,50,50,64,20,12,12,39,45,45,74,49,51,79,67,72,72,8,72,65,24,19,79,34,34,36,11,42,42,58,58,58,22,22,45,23,20,76,30,30,57,57,57,18,25,60,60,73,73,51,51,46,46,46,46,72,72,72,44,49,49,47,69,38,38,50,50,71,71,39,59,59,87,13,45,45,45,19,19,19,66,28,71,71,15,15,15,28,28,19,19,19,29,29,29,48,64,59,59,41,41,41,51,46,46,31,70,16,61,56,56,56,20,61,24,43,43,69,79,79,31,70,19,75,96,96,7,64,64,64,64,64,64,64,64,15,15,42,99,18,60,60,13,13,13,13,13,99,99,85,86,86,27,66,49,49,59,44,44,66,99,99,85,28,28,28,64,59,59,59,64,19,26,64,64,64,99,43,39,39,38,18,82,37,42,64,30,19,99,99,99,12,12,72,72,57,43,43,59,24,24,24,24,23,23,31,31,23,27,34,34,42,38,99,99,99,83,30,30,23,23,23,77,98,98,99,99,60,60,24,45,83,50,50,50,26,21,33,7,35,77,77,77,55,55,7,28,43,43,47,67,67,15,15,15,15,29,11,11,48,15,15,29,46,53,53,83,33,40,40,18,18,18,18,16,16,36,36,28,28,28,28,99,64,99,33,33,58,68,41,68,68,68,63,46,46,55,55,55,55,68,47,74,60,23,59,80,80,80,68,73,73,73,73,74,80,48,48,68,63,63,82,39,39,36,36,36,36,37,82,82,82,109,46,109,4,4,80,65,50,50,25,25,13,13,55,109,59,59,76,36,36,74,74,50,50,50,34,34,14,30,10,10,109,58,71,71,22,22,28,83,43,43,22,64,64,64,64,45,45,72,72,72,72,72,72,52,52,87,83,50,50,50,50,30,30,109,14,14,25,14,12,36,68,80,13,87,87,87,87,57,57,57,51,51,18,18,76,76,28,56,41,36,80,14,49,71,71,71,18,80,50,50,20,20,20,61,61,6,41,63,80,80,54,33,29,30,20,30,113,53,53,41,39,47,47,70,70,17,46,11,107,107,55,40,80,70,26,26,42,15,15,15,80,65,107,107,30,60,60,60,60,60,60,66,58,16,80,80,80,80,24,32,30,27,27,50,50,50,25,25,25,42,42,42,18,84,84,84,49,49,43,43,43,43,43,43,68,43,43,43,48,45,32,32,70,73,76,76,35,35,20,10,37,95,95,95,56,56,51,62,62,62,64,64,60,22,22,22,81,81,81,81,81,81,81,53,81,81,81,81,81,49,49,12,23,23,25,58,9,74,22,22,27,28,28,45,64,74,72,72,72,11,13,56,56,56,56,45,45,64,72,98,98,98,41,111,98,98,98,30,30,18,111,45,93,93,93,6,27,40,61,53,53,53,61,14,14,111,111,111,98,34,34,44,44,16,16,16,20,20,20,6,36,98,98,66,87,87,51,51,39,73,4,55,111,111,72,72,74,74,19,19,22,50,50,48,14,14,52,111,40,60,60,60,53,8,66,66,33,33,33,61,111,79,24,24,109,109,47,109,95,38,32,7,7,66,66,95,74,74,61,65,62,54,111,111,111,111,95,39,18,29,29,28,29,59,59,59,38,35,35,69,69,8,111,28,57,57,69,69,69,32,58,37,37,72,66,86,86,12,12,27,68,48,85,51,68,68,86,63,63,63,50,19,19,23,60,74,21,21,34,58,23,58,58,51,51,51,71,35,32,32,25,30,58,58,30,76,49,49,49,49,49,58,58,72,54,13,13,72,79,79,26,26,26,37,38,89,89,89,35,14,21,21,21,75,6,77,77,77,64,64,64,18,18,18,75,29,58,16,26,26,17,17,64,64,64,75,75,50,50,49,40,40,63,75,85,51,37,51,51,19,19,19,19,63,69,58,19,23,23,82,55,55,55,82,82,55,82,73,73,82,41,82,82,6,48,48,64,73,73,23,12,26,26,26,26,43,43,43,14,57,48,7,37,75,10,44,44,44,68,82,64,64,64,73,75,75,46,71,25,25,54,19,19,74,78,47,86,86,86,44,44,10,105,105,105,58,58,86,86,86,86,86,86,86,86,68,59,50,63,20,20,26,25,25,16,86,44,44,34,34,31,31,49,60,60,64,64,30,56,41,41,46,49,4 ...

# %%
print("Visit months:")
_ = count_values(condition_one["ENCOUNTER_START"].dt.month, 4, key_name="Month")
print()

print("Immunization:")
_ = count_values(condition_one["IMMUN_DESCRIPTION"], 4)
print()

print("Type of condition-admission:")
_ = count_values(condition_one["ENCOUNTER_ENCOUNTERCLASS"], ignore_number=True)
print()

print("Type of condition-admission:")
_ = count_values(condition_one["ENCOUNTER_ENCOUNTERCLASS"], ignore_number=True)
print()

print("Life-style patients:")
_ = count_values(condition_one["OBS_VALUE"], ignore_number=True)
print()

print("Allergy:")
_ = count_values(condition_one["ALLERGY_DESCRIPTION"], ignore_number=True)
print()
# Out:
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   4   |  126  |
# |   7   |  114  |
# |   11  |  110  |
# |   5   |  105  |
# +-------+-------+
#
# Immunization:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  1248 |
# +------------+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  1248 |
# +------------+-------+
#
# Life-style patients:
# +--------------------------+-------+
# |           KEY            | VALUE |
# +--------------------------+-------+
# |       Never smoker       |  108  |
# |      Former smoker       |   34  |
# | Current every day smoker |   1   |
# +--------------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+

# %% [markdown]
# # Invistigate second condition: Acute viral pharyngitis (disorder)
#
# Acute viral pharyngitis is a medical condition commonly known as a sore throat. It is an inflammation of the pharynx, the back of the throat, usually caused by a viral infection. Symptoms include a scratchy or sore throat, pain or difficulty when swallowing, swollen glands in the neck, and fever. In most cases, it is a self-limited illness that will resolve on its own within a few days without specific treatment, but symptomatic treatment such as pain relief and hydration can help to alleviate symptoms.
#
# ```bash
# Medications:
# +------------------------------------------------------------------------------------------------------+-------+
# |                                                 KEY                                                  | VALUE |
# +------------------------------------------------------------------------------------------------------+-------+
# |                                                 None                                                 |  630  |
# |                              Penicillin V Potassium 250 MG Oral Tablet                               |   9   |
# |                                Hydrochlorothiazide 25 MG Oral Tablet                                 |   4   |
# |                120 ACTUAT Fluticasone propionate 0.044 MG/ACTUAT Metered Dose Inhaler                |   3   |
# +------------------------------------------------------------------------------------------------------+-------+
#
#
# Median age:
# AGE (median): 46
#
#  Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  653  |
# +---------------+-------+
#
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   1   |   67  |
# |   7   |   66  |
# |   10  |   61  |
# |   2   |   56  |
# +-------+-------+
#
# Immunization:
# +------+-------+
# | KEY  | VALUE |
# +------+-------+
# | None |  653  |
# +------+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  653  |
# +------------+-------+
#
# Life-style patients:
# +--------------------------+-------+
# |           KEY            | VALUE |
# +--------------------------+-------+
# |       Never smoker       |   31  |
# |      Former smoker       |   6   |
# | Current every day smoker |   1   |
# +--------------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
#
# ```

# %%
condition_two = data[data["COND_DESCRIPTION"].apply(lambda x: contains_x(x, "Acute viral pharyngitis (disorder)"))]
condition_two.head(2)
# Out:
#                               PATIENT_Id PATIENT_BIRTHDATE PATIENT_DEATHDATE  \
# 8   8d4c4326-e9de-4f45-9a4c-f8c36bff89ae        1978-05-27               NaT
# 12  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a        1996-10-18               NaT
#
#     PATIENT_SSN PATIENT_FIRST   PATIENT_LAST PATIENT_MARITAL PATIENT_RACE  \
# 8   999-85-4926    Mariana775  Rutherford999               M        white
# 12  999-60-7372   Gregorio366         Auer97             NaN        white
#
#    PATIENT_ETHNICITY PATIENT_GENDER  ... ALLERGY_DESCRIPTION DEVICE_START  \
# 8        nonhispanic              F  ...                 NaN          NaN
# 12       nonhispanic              M  ...                 NaN          NaN
#
#    DEVICE_STOP DEVICE_CODE DEVICE_DESCRIPTION  DEVICE_UDI  IMMUN_DATE  \
# 8          NaT         NaN                NaN         NaN         NaN
# 12         NaT         NaN                NaN         NaN         NaN
#
#     IMMUN_CODE  IMMUN_DESCRIPTION  IMMUN_BASE_COST
# 8          NaN                NaN              NaN
# 12         NaN                NaN              NaN
#
# [2 rows x 128 columns]

# %%
print("Medication: ")
_ = count_values(condition_two['MEDICATION_DESCRIPTION'], topk=10)

print()
print(" Median age: ")
print(f"AGE (median): {int(condition_two['PATIENT_AGE'].median())}")

print()
print(" Patient state: ")
_ = count_values(condition_two['PATIENT_STATE'], topk=1)

print()
print("Visit months:")
_ = count_values(condition_two["ENCOUNTER_START"].dt.month, 4, key_name="Month")
print()

print("Immunization:")
_ = count_values(condition_two["IMMUN_DESCRIPTION"], 4)
print()

print("Type of condition-admission:")
_ = count_values(condition_two["ENCOUNTER_ENCOUNTERCLASS"], ignore_number=True)
print()

print("Life-style patients:")
_ = count_values(condition_two["OBS_VALUE"], ignore_number=True)
print()

print("Allergy:")
_ = count_values(condition_two["ALLERGY_DESCRIPTION"], ignore_number=True)
print()
# Out:
# Medication:
# +------------------------------------------------------------------------------------------------------+-------+
# |                                                 KEY                                                  | VALUE |
# +------------------------------------------------------------------------------------------------------+-------+
# |                              Penicillin V Potassium 250 MG Oral Tablet                               |   9   |
# |                                Hydrochlorothiazide 25 MG Oral Tablet                                 |   4   |
# |                120 ACTUAT Fluticasone propionate 0.044 MG/ACTUAT Metered Dose Inhaler                |   3   |
# |                  NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler                  |   3   |
# |                          Atenolol 50 MG / Chlorthalidone 25 MG Oral Tablet                           |   3   |
# |                              Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray                               |   3   |
# | insulin human  isophane 70 UNT/ML / Regular Insulin  Human 30 UNT/ML Injectable Suspension [Humulin] |   2   |
# |    60 ACTUAT Fluticasone propionate 0.25 MG/ACTUAT / salmeterol 0.05 MG/ACTUAT Dry Powder Inhaler    |   1   |
# |                                    Clopidogrel 75 MG Oral Tablet                                     |   1   |
# |                                    Simvastatin 20 MG Oral Tablet                                     |   1   |
# +------------------------------------------------------------------------------------------------------+-------+
#
#  Median age:
# AGE (median): 46
#
#  Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  653  |
# +---------------+-------+
#
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   1   |   67  |
# |   7   |   66  |
# |   10  |   61  |
# |   2   |   56  |
# +-------+-------+
#
# Immunization:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  653  |
# +------------+-------+
#
# Life-style patients:
# +--------------------------+-------+
# |           KEY            | VALUE |
# +--------------------------+-------+
# |       Never smoker       |   31  |
# |      Former smoker       |   6   |
# | Current every day smoker |   1   |
# +--------------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+

# %% [markdown]
# # Invistigate Third condition: Acute bronchitis (disorder)
#
# Acute bronchitis is an inflammation of the bronchial tubes, which are the airways that carry air to the lungs. It is usually caused by a viral infection, although bacterial infections, exposure to air pollution, and other factors can also contribute to the condition. Symptoms of acute bronchitis include cough, chest discomfort or pain, fever, and shortness of breath. In most cases, acute bronchitis clears up on its own within a few weeks.
#
# ```bash
# Medications:
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                                                        KEY                                                        | VALUE |
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                                          Acetaminophen 325 MG Oral Tablet                                         |  434  |
# | Acetaminophen 21.7 MG/ML / Dextromethorphan Hydrobromide 1 MG/ML / doxylamine succinate 0.417 MG/ML Oral Solution |  126  |
# |                                 Atenolol 50 MG / Chlorthalidone 25 MG Oral Tablet                                 |   7   |
# +-------------------------------------------------------------------------------------------------------------------+-------+
#
# Median age:
# AGE (median): 47
#
#  Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  563  |
# +---------------+-------+
#
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   7   |   55  |
# |   8   |   54  |
# |   4   |   52  |
# |   6   |   51  |
# +-------+-------+
#
# Immunization:
# +------+-------+
# | KEY  | VALUE |
# +------+-------+
# | None |  563  |
# +------+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  562  |
# | outpatient |   1   |
# +------------+-------+
#
# Life-style patients:
# +---------------------+-------+
# |         KEY         | VALUE |
# +---------------------+-------+
# |     Never smoker    |   49  |
# |    Former smoker    |   13  |
# |     heterosexual    |   1   |
# |   not HIV positive  |   1   |
# |  No signs/symptoms  |   1   |
# | Patient is homeless |   1   |
# |          No         |   1   |
# +---------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
# ```

# %%
condition_three = data[data["COND_DESCRIPTION"].apply(lambda x: contains_x(x, "Acute bronchitis (disorder)"))]
condition_three.head(2)
# Out:
#                               PATIENT_Id PATIENT_BIRTHDATE PATIENT_DEATHDATE  \
# 10  10339b10-3cd1-4ac3-ac13-ec26728cb592        1992-06-02               NaT
# 19  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a        1996-10-18               NaT
#
#     PATIENT_SSN PATIENT_FIRST PATIENT_LAST PATIENT_MARITAL PATIENT_RACE  \
# 10  999-27-3385     Jayson808     Fadel536               M        white
# 19  999-60-7372   Gregorio366       Auer97             NaN        white
#
#    PATIENT_ETHNICITY PATIENT_GENDER  ... ALLERGY_DESCRIPTION DEVICE_START  \
# 10       nonhispanic              M  ...                 NaN          NaN
# 19       nonhispanic              M  ...                 NaN          NaN
#
#    DEVICE_STOP DEVICE_CODE DEVICE_DESCRIPTION  DEVICE_UDI  IMMUN_DATE  \
# 10         NaT         NaN                NaN         NaN         NaN
# 19         NaT         NaN                NaN         NaN         NaN
#
#     IMMUN_CODE  IMMUN_DESCRIPTION  IMMUN_BASE_COST
# 10         NaN                NaN              NaN
# 19         NaN                NaN              NaN
#
# [2 rows x 128 columns]

# %%
print("Medication: ")
_ = count_values(condition_three['MEDICATION_DESCRIPTION'], topk=10)

print()
print(" Median age: ")
print(f"AGE (median): {int(condition_three['PATIENT_AGE'].median())}")

print()
print(" Patient state: ")
_ = count_values(condition_three['PATIENT_STATE'], topk=1)

print()
print("Visit months:")
_ = count_values(condition_three["ENCOUNTER_START"].dt.month, 4, key_name="Month")
print()

print("Immunization:")
_ = count_values(condition_three["IMMUN_DESCRIPTION"], 4)
print()

print("Type of condition-admission:")
_ = count_values(condition_three["ENCOUNTER_ENCOUNTERCLASS"], ignore_number=True)
print()

print("Life-style patients:")
_ = count_values(condition_three["OBS_VALUE"], ignore_number=True)
print()

print("Allergy:")
_ = count_values(condition_three["ALLERGY_DESCRIPTION"], ignore_number=True)
print()
# Out:
# Medication:
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                                                        KEY                                                        | VALUE |
# +-------------------------------------------------------------------------------------------------------------------+-------+
# |                                          Acetaminophen 325 MG Oral Tablet                                         |  434  |
# | Acetaminophen 21.7 MG/ML / Dextromethorphan Hydrobromide 1 MG/ML / doxylamine succinate 0.417 MG/ML Oral Solution |  126  |
# |                                 Atenolol 50 MG / Chlorthalidone 25 MG Oral Tablet                                 |   7   |
# |                                       Hydrochlorothiazide 25 MG Oral Tablet                                       |   6   |
# |                                           Verapamil Hydrochloride 40 MG                                           |   5   |
# |                                            Digoxin 0.125 MG Oral Tablet                                           |   5   |
# |                                          Warfarin Sodium 5 MG Oral Tablet                                         |   5   |
# |        insulin human  isophane 70 UNT/ML / Regular Insulin  Human 30 UNT/ML Injectable Suspension [Humulin]       |   4   |
# |               amLODIPine 5 MG / Hydrochlorothiazide 12.5 MG / Olmesartan medoxomil 20 MG Oral Tablet              |   3   |
# |                                     Nitroglycerin 0.4 MG/ACTUAT Mucosal Spray                                     |   3   |
# +-------------------------------------------------------------------------------------------------------------------+-------+
#
#  Median age:
# AGE (median): 47
#
#  Patient state:
# +---------------+-------+
# |      KEY      | VALUE |
# +---------------+-------+
# | Massachusetts |  563  |
# +---------------+-------+
#
# Visit months:
# +-------+-------+
# | Month | VALUE |
# +-------+-------+
# |   7   |   55  |
# |   8   |   54  |
# |   4   |   52  |
# |   6   |   51  |
# +-------+-------+
#
# Immunization:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
#
# Type of condition-admission:
# +------------+-------+
# |    KEY     | VALUE |
# +------------+-------+
# | ambulatory |  562  |
# | outpatient |   1   |
# +------------+-------+
#
# Life-style patients:
# +---------------------+-------+
# |         KEY         | VALUE |
# +---------------------+-------+
# |     Never smoker    |   49  |
# |    Former smoker    |   13  |
# |     heterosexual    |   1   |
# |   not HIV positive  |   1   |
# |  No signs/symptoms  |   1   |
# | Patient is homeless |   1   |
# |          No         |   1   |
# +---------------------+-------+
#
# Allergy:
# +-----+-------+
# | KEY | VALUE |
# +-----+-------+
# +-----+-------+
